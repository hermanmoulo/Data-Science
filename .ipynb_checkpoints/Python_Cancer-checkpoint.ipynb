# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("breast-cancer-wisconsin.csv",delimiter=",")
dataset
# Out:
#      Sample code number   Clump Thickness   Uniformity of Cell Size  \
# 0               1000025                 5                         1
# 1               1002945                 5                         4
# 2               1015425                 3                         1
# 3               1016277                 6                         8
# 4               1017023                 4                         1
# 5               1017122                 8                        10
# 6               1018099                 1                         1
# 7               1018561                 2                         1
# 8               1033078                 2                         1
# 9               1033078                 4                         2
# 10              1035283                 1                         1
# 11              1036172                 2                         1
# 12              1041801                 5                         3
# ...

# %%
#dimension du dataset
print(dataset.shape)
# Out:
# (699, 11)

# %%
#affichage des premières lignes
print(dataset.head())
# Out:
#    Sample code number   Clump Thickness   Uniformity of Cell Size  \
# 0             1000025                 5                         1
# 1             1002945                 5                         4
# 2             1015425                 3                         1
# 3             1016277                 6                         8
# 4             1017023                 4                         1
#
#     Uniformity of Cell Shape   Marginal Adhesion  \
# 0                          1                   1
# 1                          4                   5
# 2                          1                   1
# 3                          8                   1
# 4                          1                   3
#
#     Single Epithelial Cell Size  Bare Nuclei   Bland Chromatin  \
# 0                             2            1                 3
# 1                             7           10                 3
# 2                             2            2                 3
# ...

# %%
#information sur les variables
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
# Sample code number              699 non-null int64
#  Clump Thickness                699 non-null int64
#  Uniformity of Cell Size        699 non-null int64
#  Uniformity of Cell Shape       699 non-null int64
#  Marginal Adhesion              699 non-null int64
#  Single Epithelial Cell Size    699 non-null int64
#  Bare Nuclei                    699 non-null object
#  Bland Chromatin                699 non-null int64
#  Normal Nucleoli                699 non-null int64
#  Mtoses                         699 non-null int64
#  Class                          699 non-null int64
# dtypes: int64(10), object(1)
# memory usage: 57.4+ KB
# None

# %%
#vérifier la distribution absolue des classes
print(y.value_counts())
# Out:
# benign       458
# malignant    241
# Name:  Class, dtype: int64

# %%
#transformation de la classe en une variable qualitative
y=y.replace([2,4],['benign', 'malignant' ])
y
# Out:
# 0         benign
# 1         benign
# 2         benign
# 3         benign
# 4         benign
# 5      malignant
# 6         benign
# 7         benign
# 8         benign
# 9         benign
# 10        benign
# 11        benign
# 12     malignant
# 13        benign
# 14     malignant
# 15     malignant
# 16        benign
# 17        benign
# 18     malignant
# 19        benign
# 20     malignant
# 21     malignant
# 22        benign
# 23     malignant
# 24        benign
# 25     malignant
# 26        benign
# 27        benign
# 28        benign
# 29        benign
#          ...
# 669    malignant
# 670    malignant
# 671       benign
# 672       benign
# 673       benign
# 674       benign
# 675       benign
# 676       benign
# 677       benign
# 678       benign
# 679       benign
# 680    malignant
# 681    malignant
# 682       benign
# 683       benign
# 684       benign
# 685       benign
# 686       benign
# 687       benign
# 688       benign
# 689       benign
# ...

# %%
#  separation des features et de la cible
X=dataset.iloc[:,:-1]
#X
#colonnes=['PassengerId','Ticket','Name']
#df.drop(colonnes, axis=1)
y=dataset.iloc[:,10]
#y=dataset[:,10]
y
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
# 5      4
# 6      2
# 7      2
# 8      2
# 9      2
# 10     2
# 11     2
# 12     4
# 13     2
# 14     4
# 15     4
# 16     2
# 17     2
# 18     4
# 19     2
# 20     4
# 21     4
# 22     2
# 23     4
# 24     2
# 25     4
# 26     2
# 27     2
# 28     2
# 29     2
#       ..
# 669    4
# 670    4
# 671    2
# 672    2
# 673    2
# 674    2
# 675    2
# 676    2
# 677    2
# 678    2
# 679    2
# 680    4
# 681    4
# 682    2
# 683    2
# 684    2
# 685    2
# 686    2
# 687    2
# 688    2
# 689    2
# 690    2
# 691    4
# 692    2
# 693    2
# 694    2
# 695    2
# 696    4
# 697    4
# 698    4
# Name:  Class, Length: 699, dtype: int64

# %%
dataset['Class']=donnees['Class'].replace([2,4],['benign','malignant' ])
dataset
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-9c3230f7bb73> in <module>
# ...
